# %% [markdown]
# # Jour 1 — Fondamentaux Python · Notebook Participant
# ## Formation Beobank · SAS → Python · Orsys
#
# **Instructions :** Complétez chaque cellule en suivant les commentaires `# TODO`.
# Reproduisez le code projeté à l'écran et répondez aux exercices.
#
# > Données disponibles dans `../data/` — CTR.csv, TIE.csv, TXN_X_CTR.csv, etc.
#
# 📎 **Comparaisons SAS ↔ Python détaillées :** voir `../sas_vs_python/SAS_vs_Python.ipynb`.

# %% [markdown]
# ## Module 1 — Algorithmes et introduction à Python
# ### 1.1 Qu'est-ce qu'un algorithme ?

# %% [markdown]
# Un **algorithme** est une suite d'étapes précises qui résout un problème, écrite AVANT le code.
#
# **Exercice de réflexion (pas de code) :** décrivez en 5 étapes numérotées, en français,
# l'algorithme pour calculer le pourcentage de contrats ouverts dans un portefeuille.

# %% [markdown]
# ### 1.2 Reproduire : règles de nommage

# %%
# TODO : créer 3 variables avec des noms VALIDES et lisibles (snake_case) pour :
# - un identifiant de compte
# - un solde
# - un statut
# Afficher les 3 avec print()

# --- votre code ---

# %% [markdown]
# ### 1.3 Reproduire : input() et print()

# %%
# TODO 1 : afficher "Bonjour Beobank" avec print()
# TODO 2 : afficher solde et devise sur la même ligne avec sep=" | "
# TODO 3 : simuler un input() : identifiant_saisi = "AC00099" puis l'afficher

# --- votre code ---

# %% [markdown]
# ## Module 2 — Variables, Types, F-strings
# ### 2.1 Reproduire : Variables Beobank

# %%
# Reproduisez le code du formateur ici
# Créez 4 variables : idt_ac, solde_ctr, nb_transactions, compte_actif
# Affichez leur type avec type()

# --- votre code ---

# %% [markdown]
# ### 2.2 Reproduire : Conversion de types

# %%
# Reproduisez la conversion :
# solde_texte = "15234.50"  →  solde_nombre (float)
# Affichez les deux types

# --- votre code ---

# %% [markdown]
# ### 2.3 Reproduire : F-strings

# %%
# Reproduisez le f-string complet :
# idt_ac, devise, solde, statut → message formaté avec :.2f
# Essayez aussi le format :,.2f (avec séparateur de milliers)

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 1 — Intérêts mensuels

# %%
# Calculez les intérêts mensuels pour le compte AC00042
# solde = 24500.0, taux_annuel = 0.035

idt_ac      = "AC00042"
solde       = 24500.0
taux_annuel = 0.035

# TODO 1 : calculer interets_mensuels = solde * taux_annuel / 12
# TODO 2 : arrondir à 2 décimales avec round()
# TODO 3 : print f-string → "Compte AC00042 — Intérêts du mois : XX.XX EUR"

# --- votre code ---

# %% [markdown]
# ## Module 3 — Opérateurs
# ### 3.1 Reproduire : opérateurs arithmétiques

# %%
a, b = 17, 5

# TODO : afficher a+b, a-b, a*b, a/b, a//b, a%b, a**b avec des commentaires
# TODO : convertir 26 mois en années + mois restants avec // et %

# --- votre code ---

# %% [markdown]
# ### 3.2 Reproduire : comparaison et logique

# %%
solde  = -150.0
statut = "1"

# TODO : tester ==, !=, >, >=, <, <=
# TODO : construire compte_a_risque avec and, a_verifier avec or, compte_ferme avec not

# --- votre code ---

# %% [markdown]
# ### 3.3 Reproduire : assignation augmentée

# %%
solde = 1000.0

# TODO : solde += 250 puis solde -= 100 puis solde *= 1.035 (afficher à chaque étape)

# --- votre code ---

# %% [markdown]
# ## Module 4 — Conditions if / elif / else
# ### 4.1 Reproduire : Classifier un statut

# %%
# Reproduisez le bloc if/elif/else pour COD_ECV_CTR
# Testez avec cod_ecv_ctr = "4"

cod_ecv_ctr = "4"

# TODO : écrire if/elif/else → libelle

# --- votre code ---

# %% [markdown]
# ### 4.2 Reproduire : Conditions composées

# %%
# Reproduisez l'exemple with and/or pour détecter un compte "à risque"
# cod_ecv_ctr = "1", solde = -250.0

cod_ecv_ctr = "1"
solde       = -250.0

# TODO : if avec and + or → variable risque

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 2 — Niveau de risque

# %%
# Classifiez ce contrat par niveau de risque
cod_ecv = "3"
solde   = -1200.0
devise  = "EUR"

# TODO : if/elif/else avec 4 niveaux (voir slide / notebook formateur)
# Résultat attendu : "Élevé"

# --- votre code ---

# %% [markdown]
# ## Module 5 — Boucles
# ### 5.1 Reproduire : for + range

# %%
# Reproduisez la boucle de rapport mensuel (12 mois)
# Puis la boucle sur la liste de devises

# --- votre code ---

# %% [markdown]
# ### 5.2 Reproduire : enumerate

# %%
# Reproduisez l'exemple enumerate sur la liste de comptes
comptes = ["AC00001", "AC00042", "AC00099", "AC00150"]

# TODO : boucle for rang, compte in enumerate(comptes, start=1)

# --- votre code ---

# %%
# TODO : boucler for i in range(10) et n'afficher que les multiples de 3
#        avec continue pour sauter les autres

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 3 — Analyser les statuts

# %%
statuts = ["1","1","3","4","1","6","2","1","4"]

# TODO 1 : compter nb_ouverts (statut "1") avec for + if
# TODO 2 : afficher chaque contrat avec enumerate
# TODO 3 : calculer % d'ouverts = nb_ouverts / len(statuts) * 100

# --- votre code ---

# %% [markdown]
# ## Module 6 — Listes et Compréhensions
# ### 6.1 Reproduire : Opérations sur liste

# %%
# Reproduisez les opérations sur la liste devises :
# accès par index, tranche, len, append, sort

devises = ["EUR", "USD", "GBP", "CHF"]

# TODO : tester devises[0], devises[-1], devises[1:3], len, append, sort

# --- votre code ---

# %% [markdown]
# ### 6.2 Reproduire : List comprehensions

# %%
soldes = [15234, -500, 8900, 0, 32100, -120, 4500, 1200, -85, 9999]

# TODO 1 : extraire les soldes positifs en comprehension
# TODO 2 : calculer les intérêts (taux 3.5%) sur les soldes positifs

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 4 — Filtrer les soldes

# %%
soldes = [15234, -500, 8900, 0, 32100, -120, 4500, 1200, -85, 9999]

# TODO 1 : extraire les soldes NÉGATIFS (comprehension)
# TODO 2 : sum() des négatifs
# TODO 3 : liste de labels "OK"/"NÉGATIF" (comprehension avec if/else)

# --- votre code ---

# %% [markdown]
# ## Module 7 — Concaténation, duplication et réduction
# ### 7.1 Reproduire : + et *

# %%
prenom, nom = "Jean", "Dupont"
liste_a, liste_b = ["EUR", "USD"], ["GBP", "CHF"]

# TODO 1 : concaténer prenom + nom (avec un espace)
# TODO 2 : concaténer liste_a + liste_b
# TODO 3 : créer "-" répété 20 fois, et [0] répété 5 fois

# --- votre code ---

# %% [markdown]
# ### 7.2 Reproduire : réduction

# %%
soldes = [15234, -500, 8900, 0, 32100]

# TODO : afficher len(), sum(), min(), max() de soldes
# TODO : any() → au moins un négatif ? / all() → tous positifs ?

# --- votre code ---

# %% [markdown]
# ## Module 8 — Tuples et Dictionnaires
# ### 8.1 Reproduire : Tuples

# %%
# Reproduisez l'exemple de tuple agence avec déballage
agence = ("Bruxelles Centre", 50.8503, 4.3517)

# TODO : déballage ville, lat, lon → afficher avec f-string

# Reproduisez la liste de tuples portefeuille + boucle for avec déballage

# --- votre code ---

# %% [markdown]
# ### 8.2 Reproduire : Dictionnaires

# %%
# Reproduisez le dictionnaire statuts (6 entrées)
# Testez statuts.get("3", "Inconnu")
# Bouclez sur .items() pour tout afficher

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 5 — Catalogue de produits

# %%
# TODO 1 : créer dict types_comptes : "C"->"Compte courant", "E"->"Épargne", "I"->"Investissement"
# TODO 2 : créer liste de tuples portefeuille avec 5 entrées
# TODO 3 : boucler, afficher libellé + solde, compter les "C"

# --- votre code ---

# %% [markdown]
# ## Module 9 — Chaînes de caractères, Sets et Unpacking
# ### 9.1 Reproduire : méthodes de chaînes

# %%
# Reproduisez : nettoyage d'un identifiant avec .strip().upper()
# Puis .replace(), .split() et .join() sur une ligne "AC00001;15234.50;EUR;1"

# --- votre code ---

# %% [markdown]
# ### 9.2 Reproduire : Sets

# %%
statuts_observes = ["1", "1", "3", "4", "1", "6", "2", "1", "4"]

# TODO : convertir en set, afficher le nombre de statuts différents
# TODO : avec comptes_janvier = {"AC001","AC002","AC003"} et comptes_fevrier = {"AC002","AC003","AC004"}
#        afficher intersection (&), union (|) et différence (-)

# --- votre code ---

# %% [markdown]
# ### 9.3 Reproduire : Unpacking

# %%
soldes = [15234, 8900, -500, 32100, 4500, 1200]

# TODO : premier, *autres_soldes = soldes → afficher les deux
# TODO : premier, *milieu, dernier = soldes → afficher les trois

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 6 — Nettoyer et regrouper des identifiants

# %%
identifiants_bruts = ["  ac00001", "AC00002  ", "ac-00003", " AC00001 ", "AC00002"]

# TODO 1 : nettoyer chaque identifiant (.strip().upper().replace("-", ""))
# TODO 2 : stocker les résultats dans une liste identifiants_propres
# TODO 3 : utiliser un set pour compter le nombre d'identifiants VRAIMENT différents

# --- votre code ---

# %% [markdown]
# ## Module 10 — Fonctions, Lambda, try/except
# ### 10.1 Reproduire : def classifier_solde

# %%
# Reproduisez la fonction classifier_solde(solde, seuil_bas=500, seuil_haut=10000)
# Testez avec 250, 5000 et 25000

# --- votre code ---

# %% [markdown]
# ### 10.2 Reproduire : Lambda

# %%
# Reproduisez la lambda libelle_statut + utilisation avec map() et filter()

soldes = [500, 1500, 12000, 200, 45000]

# --- votre code ---

# %% [markdown]
# ### 10.3 Reproduire : try/except

# %%
# Reproduisez la fonction convertir_solde_robuste(valeur)
# Testez avec ["15234.50", ".", "N/A", None, "8900"]

# --- votre code ---

# %% [markdown]
# ### Reproduire : gestion avancée des exceptions

# %%
# TODO 1 : écrire diviser(a, b) avec except ZeroDivisionError, except TypeError, finally
# TODO 2 : écrire verifier_solde(solde) qui raise ValueError si solde < -10000
# TODO 3 : appeler verifier_solde(-50000) dans un try/except et afficher le message

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 7 — Enrichir un enregistrement

# %%
# Écrivez la fonction enrichir_compte(compte_dict)
# Elle doit ajouter : categorie_solde, libelle_statut, interets_mensuels
# Utilisez try/except pour le solde

compte_test = {"idt_ac": "AC00001", "sld_ctr": "15234.50", "cod_ecv_ctr": "1"}

# --- votre code ---

# %% [markdown]
# ## Module 11 — Fonctions avancées : portée, docstrings, type hints
# ### 11.1 Reproduire : portée des variables

# %%
taux_global = 0.035

# TODO : écrire calculer_interets(solde) avec une variable locale taux_local
# TODO : écrire incrementer_compteur() qui modifie une variable globale (mot-clé global)

# --- votre code ---

# %% [markdown]
# ### 11.2 Reproduire : docstring

# %%
# TODO : écrire calculer_interets_mensuels(solde, taux_annuel=0.035) avec une docstring
#        (résumé + paramètres + retour), puis help() dessus

# --- votre code ---

# %% [markdown]
# ### 11.3 Reproduire : type hints

# %%
# TODO : réécrire la même fonction avec type hints :
#        def calculer_interets_types(solde: float, taux_annuel: float = 0.035) -> float:

# --- votre code ---

# %% [markdown]
# ### 11.4 Reproduire : fonctions built-in

# %%
valeurs = [15234, -500, 8900, 0, 32100]

# TODO : tester type(), isinstance(), sorted(), round(), abs(), zip(), enumerate()

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 8 — Fonction avec docstring et type hints

# %%
# TODO 1 : fonction classifier(solde: float) -> str avec docstring
# TODO 2 : SEUIL_FAIBLE = 5000 en variable globale
# TODO 3 : tester avec 3 valeurs

# --- votre code ---

# %% [markdown]
# ## Module 12 — Modules et imports
# ### 12.1 Reproduire : import

# %%
# TODO : import math, afficher sqrt(16) et pi
# TODO : import random, seed(42), afficher un randint(1, 100)

# --- votre code ---

# %% [markdown]
# ### 12.2 Reproduire : from...import et alias

# %%
# TODO : from math import sqrt, pi → afficher sqrt(25) et pi
# TODO : import datetime as dt → afficher dt.date.today()

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 9 — Utiliser un module

# %%
# TODO 1 : importer datetime, afficher la date du jour
# TODO 2 : importer random, seed(7), tirer un entier entre 1 et 6

# --- votre code ---

# %% [markdown]
# ## Module 13 — Lecture CSV
# ### 13.1 Reproduire : csv.DictReader

# %%
import csv

# Reproduisez la lecture de CTR.csv avec csv.DictReader
# Affichez : nombre de lignes + toutes les clés de la première ligne

contrats = []

# TODO : with open("../data/CTR.csv") + DictReader + boucle for + append

# --- votre code ---

# %% [markdown]
# ### 13.2 Reproduire : PROC FREQ

# %%
# Reproduisez le comptage des statuts avec un dict
# Affichez code + libellé + nb + % (comme PROC FREQ)

# --- votre code (utilisez la liste contrats de la cellule précédente) ---

# %% [markdown]
# ## 🏁 Exercice Final — Rapport d'inventaire du portefeuille Beobank

# %%
# Lisez CTR.csv et produisez le rapport suivant :
#
# ==================================================
#   RAPPORT D'INVENTAIRE — PORTEFEUILLE BEOBANK
# ==================================================
#   Total contrats        :    200
#   Contrats ouverts      :     XX (XX.X%)
#   Contrats inactifs     :     XX (XX.X%)
#   Solde total portefeuille : X,XXX,XXX.XX EUR
#   Solde minimum         :      -XXX.XX EUR
#   Solde maximum         :   XX,XXX.XX EUR
# ==================================================
#
# Indices :
# - SLD_CTR peut valoir "." (valeur manquante) → utiliser convertir_solde_robuste
# - Contrats inactifs : statuts "4" ou "6"
# - Utiliser sum(), min(), max() sur la liste des soldes valides

import csv

# --- votre code ---
