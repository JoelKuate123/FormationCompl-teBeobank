# %% [markdown]
# # Jour 2 — Cahier d'exercices : Listes/Dicts/Tuples · Fondamentaux Python (suite) · NumPy
# ## Formation Beobank · SAS → Python · Orsys · Notebook Participant
#
# **Ce cahier a changé de contenu.** Il ne contient plus les exercices Pandas — ceux-ci
# sont désormais entièrement dans `../cours_numpy_pandas/Cours_Pandas.ipynb` (cours
# autonome, théorie + exercices + corrections). Ce cahier Jour 2 regroupe maintenant,
# dans l'ordre de progression pédagogique :
#
# 1. **Listes, Dictionnaires, Tuples** — les exercices complets de `../cours_structures_donnees/Cours_Listes_Dicts_Tuples.ipynb`
# 2. **Suite du Jour 1** — Fonctions, Lambda, try/except, portée, modules, lecture CSV
#    (Modules 10 à 13 du Jour 1, qui viennent naturellement APRÈS les listes/dicts/tuples)
# 3. **NumPy** — les exercices complets de `../cours_numpy_pandas/Cours_NumPy.ipynb`
#
# **Instructions :** ce cahier ne contient QUE les énoncés (pas de théorie, pas de
# correction) — c'est un cahier de PRATIQUE. Pour la théorie détaillée et les
# corrections, ouvrez en parallèle :
# - `../cours_structures_donnees/Cours_Listes_Dicts_Tuples.ipynb` (Parties 1-2)
# - `../cours_numpy_pandas/Cours_NumPy.ipynb` (Partie 3)
#
# Complétez chaque cellule `# --- votre code ---`. Les données sont dans `../data/`.
#
# 📎 **Comparaisons SAS ↔ Python détaillées :** voir `../sas_vs_python/SAS_vs_Python.ipynb`.
# 📎 **Pandas (Jour 2 théorie/pratique en salle) :** voir `../formateur/Jour2_Formateur.ipynb`
# (support de projection du formateur) et `../cours_numpy_pandas/Cours_Pandas.ipynb` (cahier autonome).

# %% [markdown]
# ---
# # Partie 1 — Listes, Dictionnaires, Tuples
#
# *Théorie complète et méthodes détaillées : `../cours_structures_donnees/Cours_Listes_Dicts_Tuples.ipynb`*

# %% [markdown]
# ## A. Listes

# %% [markdown]
# ### ✏️ Exercice 1 — Accéder aux devises

# %%
devises = ["EUR", "USD", "GBP", "CHF", "EUR", "USD"]

# TODO 1 : afficher la 1ère et la dernière devise de la liste
# TODO 2 : afficher les 3 premières devises avec le slicing
# TODO 3 : vérifier si "JPY" est présent dans la liste avec "in"

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 2 — Corriger un solde

# %%
comptes_soldes = [1200.0, -300.0, 8700.0, 45000.0]

# TODO 1 : corriger le solde d'index 1 en le remplaçant par -250.0
# TODO 2 : remplacer les 2 premiers soldes (index 0 et 1) par [1500.0, -200.0] en une seule instruction

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 3 — Compléter le portefeuille

# %%
comptes = ["AC101", "AC102"]

# TODO 1 : ajouter "AC103" à la fin avec .append()
# TODO 2 : ajouter ["AC104", "AC105"] à la fin avec .extend()
# TODO 3 : insérer "AC100" en première position avec .insert()

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 4 — Nettoyer une liste de comptes clôturés

# %%
comptes_actifs = ["AC201", "AC202", "AC203", "AC204", "AC205"]

# TODO 1 : "AC203" a été clôturé -> le supprimer avec .remove()
# TODO 2 : retirer le dernier compte de la liste avec .pop() et afficher lequel a été retiré
# TODO 3 : supprimer le compte en première position avec del

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 5 — Afficher un rapport de soldes

# %%
soldes = [1200.0, -300.0, 8700.0, 45000.0]

# TODO 1 : boucler avec for simple et afficher chaque solde
# TODO 2 : boucler avec enumerate() en commençant à 1, afficher "Compte n°X : solde"
#          (enumerate(liste, start=1) démarre la numérotation à 1)

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 6 — Comptes à surveiller (list comprehension)

# %%
soldes = [500.0, -1200.0, 8700.0, -50.0, 32000.0, -8000.0]

# TODO 1 : extraire les soldes négatifs avec une list comprehension
# TODO 2 : construire la liste des valeurs absolues des soldes négatifs (abs())
# TODO 3 : construire une liste d'étiquettes "RISQUE"/"OK" (if/else dans l'expression)

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 7 — Classer les comptes (tri)

# %%
soldes = [500.0, 32000.0, -1200.0, 8700.0, 45000.0]

# TODO 1 : trier soldes en place par ordre croissant avec .sort()
# TODO 2 : à partir de la liste triée, obtenir une copie décroissante avec sorted(..., reverse=True)
# TODO 3 : trier la liste ORIGINALE (non triée) par valeur absolue avec sorted(key=abs)

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 8 — Copie indépendante

# %%
comptes_originaux = ["AC301", "AC302", "AC303"]

# TODO 1 : créer un alias (comptes_originaux) SANS copy() et montrer l'effet de bord après un append
# TODO 2 : réinitialiser comptes_originaux, puis créer une vraie copie avec .copy()
# TODO 3 : modifier la copie et vérifier que l'original reste inchangé

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 9 — Fusionner deux lots de comptes

# %%
lot_a = ["AC401", "AC402"]
lot_b = ["AC403", "AC404", "AC405"]

# TODO : fusionner lot_a et lot_b avec l'opérateur + dans une nouvelle liste "tous_les_comptes"

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 10 — Toutes les méthodes de liste en une fois

# %%
statuts = ["1", "3", "1", "4", "6", "1", "2"]

# TODO 1 : compter combien de fois "1" apparaît (count)
# TODO 2 : trouver la position de la première occurrence de "4" (index)
# TODO 3 : ajouter "1" à la fin (append), puis compter à nouveau les "1"
# TODO 4 : trier la liste (sort), puis l'inverser (reverse)

# --- votre code ---

# %% [markdown]
# ## B. Dictionnaires

# %% [markdown]
# ### ✏️ Exercice 11 — Lire un enregistrement client

# %%
client = {"IDT_PI": "655010248", "COD_TYP_TIE": "1", "COD_LNG_CTR": "FR"}

# TODO 1 : afficher COD_LNG_CTR avec l'accès direct []
# TODO 2 : afficher DAT_DCS (date de décès, absente ici) avec .get() et le défaut "Vivant"
# TODO 3 : vérifier avec "in" si la clé "COD_SEX" existe dans client

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 12 — Mettre à jour un solde

# %%
compte = {"IDT_AC": "AC00099", "SLD_CTR": 500.0, "COD_DEV": "EUR"}

# TODO 1 : modifier SLD_CTR pour lui donner la valeur 750.0
# TODO 2 : avec .update(), modifier SLD_CTR à 800.0 ET ajouter COD_ECV_CTR = "1" en une fois

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 13 — Enrichir un enregistrement

# %%
compte = {"IDT_AC": "AC00200"}

# TODO 1 : ajouter la clé "SLD_CTR" avec la valeur 3200.0
# TODO 2 : ajouter, avec .update(), les clés "COD_DEV"="EUR" et "COD_ECV_CTR"="1" en une fois

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 14 — Nettoyer un enregistrement

# %%
compte = {"IDT_AC": "AC00300", "SLD_CTR": 900.0, "COD_DEV": "EUR", "TEMP": "a_supprimer"}

# TODO 1 : retirer la clé "TEMP" avec .pop() et afficher la valeur récupérée
# TODO 2 : supprimer la clé "COD_DEV" avec del
# TODO 3 : afficher le dictionnaire final

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 15 — Afficher un enregistrement complet

# %%
compte = {"IDT_AC": "AC00400", "SLD_CTR": 5600.0, "COD_DEV": "EUR", "COD_ECV_CTR": "1"}

# TODO 1 : boucler avec .items() et afficher "clé : valeur" pour chaque champ
# TODO 2 : boucler avec .values() et calculer combien de valeurs sont du texte (isinstance(v, str))

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 16 — Copie protégée

# %%
compte = {"IDT_AC": "AC00500", "SLD_CTR": 2000.0}

# TODO 1 : créer une copie avec .copy()
# TODO 2 : modifier SLD_CTR de la copie à 0.0
# TODO 3 : vérifier que le dictionnaire original n'a pas changé

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 17 — Fiche client imbriquée

# %%
client = {
    "IDT_PI": "655010248",
    "identite": {"COD_TYP_TIE": "1", "COD_SEX": "M"},
    "contact": {"ADR_EMA": "TTSAXL@E-I.COM", "NOM_VIL": "BRUXELLES"},
}

# TODO 1 : afficher le sexe du client (2 niveaux d'accès)
# TODO 2 : afficher la ville du client
# TODO 3 : boucler sur client["contact"].items() et afficher chaque clé/valeur

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 18 — Compter les statuts avec fromkeys + setdefault

# %%
statuts_observes = ["1", "1", "3", "4", "1", "6", "2", "1", "4"]

# TODO 1 : créer compteur = dict.fromkeys(["1","2","3","4","5","6"], 0)
# TODO 2 : boucler sur statuts_observes, et pour chaque statut : compteur[s] += 1
# TODO 3 : afficher compteur.items()

# --- votre code ---

# %% [markdown]
# ## C. Tuples

# %% [markdown]
# ### ✏️ Exercice 19 — Lire une agence

# %%
agence = ("Anvers Sud", 51.2094, 4.4025)

# TODO 1 : afficher le nom de l'agence (1er élément)
# TODO 2 : afficher la latitude et la longitude ensemble avec le slicing [1:]

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 20 — Déballer un enregistrement

# %%
mouvement = ("AC00042", "2026-01-15", 250.75, "SEPA")   # (compte, date, montant, type)

# TODO 1 : déballer les 4 valeurs dans compte, date, montant, type_mvt
# TODO 2 : afficher une phrase récapitulative avec un f-string

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 21 — Rapport sur une liste de tuples

# %%
mouvements = [
    ("AC00001", 250.0, "SEPA"),
    ("AC00002", -80.0, "CARTE"),
    ("AC00003", 1200.0, "VIREMENT"),
]

# TODO 1 : boucler avec unpacking (compte, montant, type_mvt) et afficher chaque ligne
# TODO 2 : calculer le total des montants avec une boucle (accumulateur)

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 22 — Analyser un tuple de statuts

# %%
statuts = ("1", "3", "1", "1", "4", "6", "1", "2")

# TODO 1 : compter combien de fois "1" apparaît avec .count()
# TODO 2 : trouver la position du premier "6" avec .index()

# --- votre code ---

# %% [markdown]
# ### 🏁 Exercice final Partie 1 — Rapport de portefeuille (listes + dicts + tuples)

# %%
import csv

# TODO 1 : lire ../data/CTR.csv avec csv.DictReader -> construire une LISTE de DICTIONNAIRES
#          nommée "contrats" (chaque élément = 1 dict = 1 ligne du fichier)
# TODO 2 : construire un dict "libelles" associant chaque code statut à son libellé
#          ("1":"Ouvert", "2":"En attente", "3":"Suspendu", "4":"Clôturé", "5":"En résiliation", "6":"Résilié")
# TODO 3 : avec dict.fromkeys() sur les clés de "libelles", construire un compteur à 0
# TODO 4 : boucler sur "contrats" et incrémenter le compteur du statut de chaque contrat
# TODO 5 : construire une LISTE DE TUPLES (code, libelle, nombre) à partir du compteur et libelles
# TODO 6 : trier cette liste de tuples par nombre décroissant avec sorted(key=..., reverse=True)
#          (key=lambda t: t[2] : trie selon le 3e élément de chaque tuple)
# TODO 7 : afficher le rapport, un tuple par ligne

# --- votre code ---

# %% [markdown]
# ---
# # Partie 2 — Suite du Jour 1 : Fonctions, Modules, Lecture CSV
#
# *Théorie complète : `../formateur/Jour1_Formateur.ipynb` (Modules 10 à 13)*

# %% [markdown]
# ## Module 10 — Fonctions, Lambda, try/except

# %% [markdown]
# ### 10.1 Reproduire : def classifier_solde

# %%
# Reproduisez la fonction classifier_solde(solde, seuil_bas=500, seuil_haut=10000)
# Testez avec 250, 5000 et 25000

# --- votre code ---

# %% [markdown]
# ### 10.2 Reproduire : Lambda

# %%
# Reproduisez la lambda libelle_statut + utilisation avec map() et filter()

soldes = [500, 1500, 12000, 200, 45000]

# --- votre code ---

# %% [markdown]
# ### 10.3 Reproduire : try/except

# %%
# Reproduisez la fonction convertir_solde_robuste(valeur)
# Testez avec ["15234.50", ".", "N/A", None, "8900"]

# --- votre code ---

# %% [markdown]
# ### Reproduire : gestion avancée des exceptions

# %%
# TODO 1 : écrire diviser(a, b) avec except ZeroDivisionError, except TypeError, finally
# TODO 2 : écrire verifier_solde(solde) qui raise ValueError si solde < -10000
# TODO 3 : appeler verifier_solde(-50000) dans un try/except et afficher le message

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 23 — Enrichir un enregistrement

# %%
# Écrivez la fonction enrichir_compte(compte_dict)
# Elle doit ajouter : categorie_solde, libelle_statut, interets_mensuels
# Utilisez try/except pour le solde

compte_test = {"idt_ac": "AC00001", "sld_ctr": "15234.50", "cod_ecv_ctr": "1"}

# --- votre code ---

# %% [markdown]
# ## Module 11 — Fonctions avancées : portée, docstrings, type hints

# %% [markdown]
# ### 11.1 Reproduire : portée des variables

# %%
taux_global = 0.035

# TODO : écrire calculer_interets(solde) avec une variable locale taux_local
# TODO : écrire incrementer_compteur() qui modifie une variable globale (mot-clé global)

# --- votre code ---

# %% [markdown]
# ### 11.2 Reproduire : docstring

# %%
# TODO : écrire calculer_interets_mensuels(solde, taux_annuel=0.035) avec une docstring
#        (résumé + paramètres + retour), puis help() dessus

# --- votre code ---

# %% [markdown]
# ### 11.3 Reproduire : type hints

# %%
# TODO : réécrire la même fonction avec type hints :
#        def calculer_interets_types(solde: float, taux_annuel: float = 0.035) -> float:

# --- votre code ---

# %% [markdown]
# ### 11.4 Reproduire : fonctions built-in

# %%
valeurs = [15234, -500, 8900, 0, 32100]

# TODO : tester type(), isinstance(), sorted(), round(), abs(), zip(), enumerate()

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 24 — Fonction avec docstring et type hints

# %%
# TODO 1 : fonction classifier(solde: float) -> str avec docstring
# TODO 2 : SEUIL_FAIBLE = 5000 en variable globale
# TODO 3 : tester avec 3 valeurs

# --- votre code ---

# %% [markdown]
# ## Module 12 — Modules et imports

# %% [markdown]
# ### 12.1 Reproduire : import

# %%
# TODO : import math, afficher sqrt(16) et pi
# TODO : import random, seed(42), afficher un randint(1, 100)

# --- votre code ---

# %% [markdown]
# ### 12.2 Reproduire : from...import et alias

# %%
# TODO : from math import sqrt, pi → afficher sqrt(25) et pi
# TODO : import datetime as dt → afficher dt.date.today()

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 25 — Utiliser un module

# %%
# TODO 1 : importer datetime, afficher la date du jour
# TODO 2 : importer random, seed(7), tirer un entier entre 1 et 6

# --- votre code ---

# %% [markdown]
# ## Module 13 — Lecture CSV

# %% [markdown]
# ### 13.1 Reproduire : csv.DictReader

# %%
import csv

# Reproduisez la lecture de CTR.csv avec csv.DictReader
# Affichez : nombre de lignes + toutes les clés de la première ligne

contrats = []

# TODO : with open("../data/CTR.csv") + DictReader + boucle for + append

# --- votre code ---

# %% [markdown]
# ### 13.2 Reproduire : PROC FREQ

# %%
# Reproduisez le comptage des statuts avec un dict
# Affichez code + libellé + nb + % (comme PROC FREQ)

# --- votre code (utilisez la liste contrats de la cellule précédente) ---

# %% [markdown]
# ### 🏁 Exercice final Partie 2 — Rapport d'inventaire du portefeuille Beobank

# %%
# Lisez CTR.csv et produisez le rapport suivant :
#
# ==================================================
#   RAPPORT D'INVENTAIRE — PORTEFEUILLE BEOBANK
# ==================================================
#   Total contrats        :    200
#   Contrats ouverts      :     XX (XX.X%)
#   Contrats inactifs     :     XX (XX.X%)
#   Solde total portefeuille : X,XXX,XXX.XX EUR
#   Solde minimum         :      -XXX.XX EUR
#   Solde maximum         :   XX,XXX.XX EUR
# ==================================================
#
# Indices :
# - SLD_CTR peut valoir "." (valeur manquante) → utiliser convertir_solde_robuste
# - Contrats inactifs : statuts "4" ou "6"
# - Utiliser sum(), min(), max() sur la liste des soldes valides

import csv

# --- votre code ---

# %% [markdown]
# ---
# # Partie 3 — NumPy
#
# *Théorie complète et corrections : `../cours_numpy_pandas/Cours_NumPy.ipynb`*

# %% [markdown]
# ### ✏️ Exercice 26 — Vérifier l'installation

# %%
# TODO : importer numpy sous l'alias np (si ce n'est pas déjà fait dans le notebook)
# TODO : afficher np.__version__

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 27 — Créer des tableaux

# %%
import numpy as np

# TODO 1 : créer un tableau 1-D "taux" avec 4 taux d'intérêt : 0.01, 0.02, 0.035, 0.05
# TODO 2 : afficher son nombre de dimensions (ndim)
# TODO 3 : créer un tableau 2-D "grille_taux" de 2 lignes x 3 colonnes avec np.zeros
#          (utile pour préparer un tableau qu'on remplira plus tard)

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 28 — Indexer un tableau

# %%
soldes = np.array([500.0, 12000.0, -300.0, 45000.0, 150.0, 8700.0])

# TODO 1 : afficher le 3e solde (index 2)
# TODO 2 : afficher le dernier solde avec un index négatif
# TODO 3 : sur un tableau 2-D de votre choix (comptes x mois), afficher le solde du compte
#          d'index 2 au mois d'index 0

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 29 — Le dernier trimestre (slicing)

# %%
solde_annuel = np.array([15000, 15200, 15400, 15100, 15600, 15900,
                          16000, 16200, 16500, 16300, 16700, 17000])   # 12 mois

# TODO 1 : extraire les 3 DERNIERS mois (dernier trimestre) avec le slicing négatif
# TODO 2 : extraire un mois sur deux (janvier, mars, mai...) avec le pas
# TODO 3 : calculer la moyenne du dernier trimestre avec np.mean()

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 30 — Convertir des soldes texte

# %%
soldes_brut = np.array(["24500.0", "-1200.5", "8700.25", "0.0"])

# TODO 1 : afficher le dtype de soldes_brut
# TODO 2 : convertir en float avec .astype(float)
# TODO 3 : calculer les intérêts à 3 % sur le tableau converti

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 31 — Copie sûre (copy vs view)

# %%
comptes = np.array([1000.0, 2000.0, 3000.0, 4000.0])

# TODO 1 : créer extrait_dangereux = comptes[1:3] (une VUE, sans copy)
# TODO 2 : modifier extrait_dangereux[0] = 0.0, puis afficher comptes -> observez l'effet de bord
# TODO 3 : refaire la même chose avec .copy() cette fois, et vérifier que comptes n'a pas changé

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 32 — Organiser 6 mois de données (reshape)

# %%
transactions_6_mois = np.array([120, 95, 140, 88, 160, 130])

# TODO 1 : afficher le shape de transactions_6_mois
# TODO 2 : réorganiser en tableau 2 lignes x 3 colonnes (2 trimestres x 3 mois) avec reshape
# TODO 3 : refaire la même chose avec reshape(2, -1)

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 33 — Classer en bouclant

# %%
soldes = np.array([500.0, -1200.0, 8700.0, 0.0, 32000.0])

# TODO : boucler sur soldes avec un for classique, et afficher pour chacun :
#        "Solde X.XX -> NEGATIF" ou "Solde X.XX -> POSITIF"

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 34 — Fusionner deux trimestres (join)

# %%
t1 = np.array([15000, 15200, 15400])   # trimestre 1
t2 = np.array([15600, 15900, 16000])   # trimestre 2

# TODO : fusionner t1 et t2 en un seul tableau de 6 valeurs avec np.concatenate

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 35 — Répartir en équipes (split)

# %%
comptes_a_appeler = np.array([f"AC{n:03d}" for n in range(1, 11)])   # 10 comptes

# TODO : répartir comptes_a_appeler en 4 lots avec np.array_split, puis afficher chaque lot

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 36 — Localiser les comptes à risque (search)

# %%
soldes = np.array([500.0, -1200.0, 8700.0, -50.0, 32000.0, -8000.0])

# TODO 1 : trouver les INDEX des soldes strictement négatifs avec np.where
# TODO 2 : afficher les valeurs correspondantes
# TODO 3 : créer un tableau d'étiquettes "RISQUE"/"OK" avec np.where(condition, si_vrai, si_faux)

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 37 — Classement des plus gros soldes (sort)

# %%
soldes = np.array([500.0, 32000.0, -1200.0, 8700.0, 45000.0])

# TODO 1 : trier soldes par ordre croissant avec np.sort()
# TODO 2 : obtenir le classement décroissant (les plus gros soldes en premier)
# TODO 3 : afficher les 3 plus gros soldes (slicing sur le résultat trié)

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 38 — Filtrer les comptes prioritaires

# %%
soldes = np.array([500.0, -1200.0, 8700.0, -50.0, 32000.0, -8000.0, 100.0])

# TODO 1 : filtrer les soldes négatifs avec un masque explicite
# TODO 2 : filtrer directement les soldes > 5000 (sans variable masque intermédiaire)
# TODO 3 : filtrer les soldes négatifs ET supérieurs à -1000 (risque modéré, pas critique)

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 39 — Simuler un tirage de contrôle qualité (random)

# %%
# TODO 1 : créer un générateur rng avec la graine 7
# TODO 2 : tirer 10 entiers aléatoires entre 1 et 200 (représentant des IDT_AC à contrôler)
# TODO 3 : tirer 5 montants selon une loi normale (moyenne 100, écart-type 30)

# --- votre code ---

# %% [markdown]
# ### ✏️ Exercice 40 — Tableau de bord d'un compte (ufunc)

# %%
mouvements = np.array([1000.0, -250.0, 500.0, -80.0, 1200.0, -400.0])   # 6 mouvements successifs

# TODO 1 : calculer le solde cumulé après chaque mouvement (np.cumsum)
# TODO 2 : afficher le solde final (dernier élément du cumul)
# TODO 3 : calculer la moyenne et l'écart-type des mouvements
# TODO 4 : afficher le mouvement le plus important en valeur absolue (np.abs puis np.max)

# --- votre code ---

# %% [markdown]
# ### 🏁 Exercice final Partie 3 — Rapport de portefeuille en NumPy pur

# %%
import csv

# TODO 1 : lire ../data/CTR.csv avec csv.DictReader (comme au Jour 1)
# TODO 2 : construire une liste Python des SLD_CTR valides (ignorer les ".")
# TODO 3 : convertir cette liste en tableau NumPy de float
# TODO 4 : afficher : nombre de comptes valides, moyenne, écart-type, min, max (arrondis à 2 décimales)
# TODO 5 : afficher le nombre et le pourcentage de comptes à solde négatif
# TODO 6 : afficher les 3 plus gros soldes, triés décroissant

# --- votre code ---

# %% [markdown]
# ---
# ## Fin du cahier Jour 2
#
# - **Corrections Listes/Dicts/Tuples :** `../cours_structures_donnees/Cours_Listes_Dicts_Tuples.ipynb`
# - **Corrections Jour 1 (Modules 10-13) :** `../formateur/Jour1_Formateur.ipynb`
# - **Corrections NumPy :** `../cours_numpy_pandas/Cours_NumPy.ipynb`
# - **Suite de la formation (Pandas) :** `../cours_numpy_pandas/Cours_Pandas.ipynb` et `../formateur/Jour2_Formateur.ipynb`
